# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltj

# %%
data = pd.read_csv('data.csv')

# %%
data = data.replace(1000,np.NaN)

# %%
data = data.drop(data.columns[[0]],axis=1)

# %%
data
# Out:
#             0          1          2          3          4          5  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1   40.885983        NaN        NaN        NaN        NaN        NaN
# 2    0.905628  85.955576        NaN        NaN        NaN        NaN
# 3   20.591904  74.742152  12.006428        NaN        NaN        NaN
# 4   34.338648  19.231769  71.163619  52.599298        NaN        NaN
# 5    2.200034  75.991570  24.094635   1.834382  44.310992        NaN
# 6    4.527526  54.708617  42.925310  30.597524  18.059073  28.129269
# 7   16.595615  83.725196   2.352766   2.691360  31.654955   4.060940
# 8   13.522081  80.265331   2.197690   2.533184  25.887485   3.428557
# 9   35.906518  29.948056  43.584142  40.482389  15.367904  40.402244
# 10   7.436231  34.367928   8.839365   1.332751  37.755832  12.040392
# 11  34.695294  74.079231  34.052379  15.846987  56.643017  45.393721
# 12   6.072356  17.287921  37.959075  16.814590   6.595780  19.620190
# ...

# %%
data.style.background_gradient(cmap='gist_rainbow')
# Out:
# /home/agam/anaconda3/lib/python3.9/site-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /home/agam/anaconda3/lib/python3.9/site-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...
